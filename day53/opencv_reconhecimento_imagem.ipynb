# %%
# %pip install opencv-python-headless
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.2 is available.
# You should consider upgrading via the 'c:\Users\Richard Junior\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
image = cv2.imread('./imagem.jpg')
if image is None:
    print("Erro: Imagem não encontrada")
else:
    print("Imagem carregada com sucesso")
# Out:
# Imagem carregada com sucesso

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')
plt.title('Imagem em tons de cinza')
plt.axis('off')
plt.show()

# %%
bordas = cv2.Canny(gray, 100, 200)
plt.imshow(bordas, cmap='gray')
plt.title('Removendo bordas')
plt.axis('off')
plt.show()

# %%
altura, largura = bordas.shape
print(f'Altura: {altura}, Largura: {largura}')
# Out:
# Altura: 1500, Largura: 1500

# %%
# Criando uma imagem RGBA (com canal alfa) para transparência
transparente = np.zeros((altura, largura, 4), dtype=np.uint8)

#para cada pixel que não for borda, deixamos transparente
transparente[ bordas != 0] = [255, 255, 255, 255]

# %%
plt.imshow(transparente, cmap='gray')
plt.title("Transparente")
plt.axis("off")
plt.show()

# %%
cv2.imwrite('imagem_transparente.png', transparente)
# Out:
# True
